# %% [markdown]
# # Afternoon Project: Create Your Digital ID Card

# %% [markdown]
# Welcome back! Let's warm up first, then build something cool with what you learned this morning 🚀

# %% [markdown]
# ## Quick Recap: Warm Up Before You Build!
#
# Before jumping into your awesome ID card project, let’s quickly review what we learned this morning.
#
# Try the short tasks below and ask for help if needed.

# %%
# This code has a bug. Can you fix it?

age = input("How old are you? ")
print("In 5 years, you will be " + age + 5)
# Out:
# How old are you? 24
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-1819143530.py in <cell line: 0>()
#       2
#       3 age = input("How old are you? ")
# ----> 4 print("In 5 years, you will be " + age + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ❓ What’s wrong with the code above?
# - Why does it break?
# - How would you fix it?

# %%
# Corrected version

age = int(input("How old are you? "))
print("In 5 years, you will be " + str(age + 5)) # you need to type cast the int to str before concatenation
# Out:
# How old are you? 24
# In 5 years, you will be 29

# %%
# 🤔 What do you think this will print?

print("3" + "5")
print(3 + 5)
print("ha" * 3)
print([1] * 4)

# %% [markdown]
# ❓ Can you guess the output?
#
# Try to predict it in your head or discuss with your neighbor before you press Run!

# %%
# Practice: Fill in the blanks to make a sentence

name = input("What's your name? ")
hobby = input("What's your favorite hobby? ")

# Fill in the print statement below
print(name + " loves to __________")

# %% [markdown]
# ### Warm-Up Quiz (Answer Mentally)
#
# 1. What does `input()` always return?
# 2. How do you convert something to an integer?
# 3. What’s the result of `"hi" * 3`?
# 4. What does `True or False` evaluate to?
# 5. What happens if you forget to cast a string before doing math?

# %% [markdown]
# ## 🪪 Project: Build Your Digital ID Card
#
# Now it’s your turn to build something fun using what you learned this morning!
#
# You’ll ask the user questions like:
# - Name
# - Age
# - School
# - Favorite color
#
# Then you’ll use `print()` to format the results into a cool **digital ID card**!
#
# Let’s go step by step

# %%
# Step 1: Ask for the user's information

# Ask for full name
# Write your code here to ask for name:
# name = ...

# Ask for age (remember to convert it to a number)
# Write your code here to ask for age:
# age = ...

# Ask for school name
# Write your code here to ask for school:
# school = ...

# Ask for favorite color
# Write your code here to ask for favorite color:
# color = ...

# %% [markdown]
# ## Step 2: Print the ID Card
#
# Now that you've collected the user's information, it's time to print it out in a clear and professional format.
#
# Your output should look like this:
#
#
# ```
# STUDENT ID CARD
# Name: Sara Ahmed
# Age: 14
# School: Green Valley School
# Favorite Color: Blue
# pgsql
# Copy
# Edit
# ```
#
# Use `print()` to format each line.

# %%
# Step 2: Print the digital ID card

# Print a title/header for your ID card
# Write your code here:
# print(...)

# Print name
# Write your code here:
# print(...)

# Print age
# Write your code here:
# print(...)

# Print school name
# Write your code here:
# print(...)

# Print favorite color
# Write your code here:
# print(...)

# Optional: Add a line to separate sections
# print("-------------------------")

# %% [markdown]
# ## Step 3: Add a Bit of Logic
#
# Let’s add a small extra feature. Show what the person's age will be **next year**.
#
# Your output could look like this:
#
# `Next year, you will be 15 years old`
#
#
# (Optional) You may also write a message if the person is under 18, like:
#
# `You are still in school.`

# %%
# Step 3: Add extra logic using math or condition

# Print how old the person will be next year
# Write your code here:
# print(...)

# (Optional) Print a message based on age
# For example, if under 18, say "You are still in school."
# print(...)

# %% [markdown]
# ## Step 4: Add Decoration (Optional but Encouraged)
#
# Let’s make the ID card look nicer using symbols like `=`, `*`, or `-`.
#
# Here's a simple example:
#
#
# ```python
# ===========================
# STUDENT ID
# Name: Sara Ahmed
# Age: 14
# School: Green Valley School
# Favorite Color: Blue
# Next year, you will be 15 years old.
# ```

# %%
# Step 4: Add style using symbols

# Add a border line using * or =
# Write your code here:
# print(...)

# Add a simple design like "ID CARD END" or other label
# Write your code here:
# print(...)

# You can add any final message if you want
# Write your code here:
# print(...)

# %% [markdown]
# ## Final Challenge: Build Your Own ID Card from Scratch
#
# Now it’s your turn to be the designer and programmer!
#
# Create your own version of the ID card **from a blank cell**. Here’s what you should include:
#
# ### Required:
# - Ask for at least **4 pieces of information** using `input()`
# - Use `int()` to convert age if needed
# - Format and print the ID card using `print()`
# - Add decoration using `-`, `=`, or `*`
# - Add at least one **math-based line** (like age next year)
#
# ### Optional (Bonus):
# - Add a line that depends on age (if under 18, print a message)
# - Add a list (e.g., 3 favorite hobbies) and print it
#
# ---
#
# Use the space below to write your own version.
